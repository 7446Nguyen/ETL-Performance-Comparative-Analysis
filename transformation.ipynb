# %%
import pandas as pd
import mysql.connector

mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="0861137MySQL!",
  database="project1"
)

# %%
print(mydb)

# %%
sql = "SELECT * from planning where site_no = 1403 "
mycursor = mydb.cursor()
mycursor.execute(sql)
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (1, 1403, 852115, '024009P4', 'OrangeLeggingsP4', 12, 9302019)
# (2, 1403, 852115, '024210P8', 'TanCasualJacketP8', 8, 9302019)
# (3, 1403, 852115, '024210P10', 'TanCasualJacketP10', 31, 9302019)
# (4, 1403, 852115, '023405P0', 'GreenDressP0', 40, 9302019)
# (5, 1403, 852115, '023408P0', 'PinkDressP0', 17, 9302019)
# (6, 1403, 852115, '023403P8', 'BlackDressP8', 16, 9302019)
# (7, 1403, 852115, '023403P10', 'BlackDressP10', 8, 9302019)
# (8, 1403, 852115, '023404P4', 'BlueDressP4', 4, 9302019)
# (9, 1403, 852115, '024408P0', 'PinkSkirtP0', 8, 9302019)
# (10, 1403, 852115, '024409P10', 'OrangeSkirtP10', 3, 9302019)
# (11, 1403, 852115, '024406P10', 'YellowSkirtP10', 4, 9302019)
# (12, 1403, 852115, '023610P6', 'TanBlouseP6', 4, 9302019)
# (13, 1403, 852115, '023803P6', 'BlackSlacksP6', 12, 9302019)
# (14, 1403, 852115, '023803P10', 'BlackSlacksP10', 20, 9302019)
# (15, 1403, 852115, '024602P10', 'WhiteCottonTeeP10', 4, 9302019)
# ...
